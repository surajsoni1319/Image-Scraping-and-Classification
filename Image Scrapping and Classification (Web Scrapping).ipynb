# %% [markdown]
# # FR - Image Scrapping and Classification (Web Scrapping)

# %%
# Importing Libraries/Dependencies
import selenium
import pandas as pd
import numpy as np
import time
from bs4 import BeautifulSoup
import requests
import re
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from collections import Counter

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

#Importing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#creating empty lists
Sarees_Image=[]
Trousers_Image=[]
Jeans_Image=[]

# %%
#search_list=['sarees','trousers','jeans']

# %%
url1='https://www.amazon.in/'

# %%
driver_1 = webdriver.Chrome("chromedriver.exe")
driver_1.get(url1)

# searching required fields
search_bar = driver_1.find_element(By.ID,"twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
search_bar.send_keys('sarees')

search_button = driver_1.find_element(By.XPATH,'//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
search_button.click()


start_page = 0
end_page = 5
for i in range(start_page,end_page+1):
    sar=driver_1.find_elements(By.XPATH,"//div[@class='a-section aok-relative s-image-tall-aspect']/img")
    for j in sar:
        image=j.get_attribute('src')
        Sarees_Image.append(image)
        
    nxt_button=driver_1.find_element(By.XPATH,"//li[@class='a-last']/a").click()
    #driver_1.get(nxt_button[i].get_attribute('href'))
    time.sleep(5)

# %%
Sarees_Image
# Out:
# ['https://m.media-amazon.com/images/I/31KxIlfQkSS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81XodnliILS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41vtARH3u+L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81ePT8kACSS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91WCQ88UV5L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61QwYQMWWSL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81Ln2cqtsLL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81JE98ug38L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/913VtoIq8DL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/511CLqMrkIL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71v25XUM21L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91GKFgnS5uL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71xE92l+GGL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91dDMDg+QTL._AC_UL320_.jpg',
# ...

# %%
len(Sarees_Image)
# Out:
# 368

# %%
driver_1 = webdriver.Chrome("chromedriver.exe")
driver_1.get(url1)

# searching required fields
search_bar = driver_1.find_element(By.ID,"twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
search_bar.send_keys('trousers for men')

search_button = driver_1.find_element(By.XPATH,'//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
search_button.click()


start_page = 0
end_page = 5
for i in range(start_page,end_page+1):
    sar=driver_1.find_elements(By.XPATH,"//div[@class='a-section aok-relative s-image-tall-aspect']/img")
    for j in sar:
        image=j.get_attribute('src')
        Trousers_Image.append(image)
        
    nxt_button=driver_1.find_element(By.XPATH,"//li[@class='a-last']/a").click()
    #driver_1.get(nxt_button[i].get_attribute('href'))
    time.sleep(5)

# %%
Trousers_Image
# Out:
# ['https://m.media-amazon.com/images/I/71unOtG+YpL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71lUwWedSQS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51ONtvmJ3PL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71LVm6k25gL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71FcvqZKY2L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61KwCbPkOyL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71yXjuYYh6L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91cu-YrCwrS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/812GuriqN4L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71UHoQ2wPzL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71Ns8ha1WRL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71UMSu5e6rL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71DqlTtu3XL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81cOaCAzIxL._AC_UL320_.jpg',
# ...

# %%
len(Trousers_Image)
# Out:
# 375

# %%
driver_1 = webdriver.Chrome("chromedriver.exe")
driver_1.get(url1)

# searching required fields
search_bar = driver_1.find_element(By.ID,"twotabsearchtextbox")    # Locating searc_bar by id                                              # clearing search_bar
search_bar.send_keys('jeans for men')

search_button = driver_1.find_element(By.XPATH,'//span[@id="nav-search-submit-text"]/input')       # Locating search_button by xpath
search_button.click()


start_page = 0
end_page = 5
for i in range(start_page,end_page+1):
    sar=driver_1.find_elements(By.XPATH,"//div[@class='a-section aok-relative s-image-tall-aspect']/img")
    for j in sar:
        image=j.get_attribute('src')
        Jeans_Image.append(image)
        
    nxt_button=driver_1.find_element(By.XPATH,"//li[@class='a-last']/a").click()
    #driver_1.get(nxt_button[i].get_attribute('href'))
    time.sleep(5)

# %%
Jeans_Image
# Out:
# ['https://m.media-amazon.com/images/I/81a+OKnHk1L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81wlV6lWAYL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81CldFPSs6L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/81FzGcAuj7L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/616xchp1ECL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71tofDe1MZL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/91qT9DFAVwL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61TwfPRLhrL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71m0W58-zQL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/31130Ux2d1L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61ZGXTSfA3L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/41zHQNFnC-L._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71BgJ8pKqQL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61CGNLHECKL._AC_UL320_.jpg',
# ...

# %%
len(Jeans_Image)
# Out:
# 368

# %%
Sarees=[]
Sarees=Sarees_Image[0:368]
len(Sarees)
# Out:
# 368

# %%
Trousers=[]
Trousers=Trousers_Image[0:368]
len(Trousers)
# Out:
# 368

# %%
Jeans=[]
Jeans=Jeans_Image[0:368]
len(Jeans)
# Out:
# 368

# %% [markdown]
# ## Hence, we have 368 images in all three lists.

# %%
# Creating Directories
import os

def directory(dir):
    current_path=os.getcwd()
    new=os.path.join(current_path,dir)
    if not os.path.exists(new):
        os.makedirs(new)
        
directory('Sarees_Images')
directory('Trousers_Images')
directory('Jeans_Images')

# Dowloading images

import shutil
import requests

# %%
for index, link in enumerate(Sarees):
    print('Downloading {0} of 368 saree images'.format(index+1))
    response=requests.get(link)
    with open('Sarees_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
for index, link in enumerate(Trousers):
    print('Downloading {0} of 368 trouser images'.format(index+1))
    response=requests.get(link)
    with open('Trousers_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)

# %%
for index, link in enumerate(Jeans):
    print('Downloading {0} of 368 jeans images'.format(index+1))
    response=requests.get(link)
    with open('Jeans_Images/img{0}.jpeg'.format(index+1),"wb") as file:
        file.write(response.content)
